# %% [markdown]
# # Data cleaning and merging dataframes

# %% [markdown]
# ## Loading multiple datasets

# %% [markdown]
# ### Classical way
#
# Reading file by file

# %%
import pandas as pd

path = '/Users/ranjitsah/Desktop/project-2/data/raw-data/'
orderlines = pd.read_csv(path + 'orderlines.csv')
orders = pd.read_csv(path + 'orders.csv')
brands = pd.read_csv(path + 'brands.csv')
products = pd.read_csv(path + 'products.csv')

df_list = [orderlines, orders, brands, products]
files = ['orderlines','orders','brands','products']

# %% [markdown]
# ### Another way
#
# Using `os` and a loop to read all the files from a directory. It's also possible to read only files with a certain extension (like `.csv`):

# %%
# import pandas as pd
# import os
# path = '../data/eniac/'
# path, dirs, files = next(os.walk(path))
# #print(files)

# # remove non-csv files
# for file in files:
#     if not file.endswith("csv"):
#         files.remove(file)

# %%
# # create empty list 
# df_list = []

# # append datasets to the list
# for file in files:
#     temp_df = pd.read_csv(path + file, sep=',')
#     df_list.append(temp_df)

# # show results
# products, orders, orderlines, brands = df_list[0], df_list[1], df_list[2], df_list[3]

# %% [markdown]
# ## Data quality
#
# ### Missing values

# %%
def check_missing_values(data): 
    print('Missing values:' + '\n' + str(data.isna().sum()))

# %%
for i in range(len(df_list)): 
    print(f'File name: {files[i]}')
    check_missing_values(df_list[i])
    print('\n')
# Out:
# File name: orderlines
# Missing values:
# id                  0
# id_order            0
# product_id          0
# product_quantity    0
# sku                 0
# unit_price          0
# date                0
# dtype: int64
#
#
# File name: orders
# Missing values:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64
#
#
# File name: brands
# Missing values:
# short    0
# long     0
# dtype: int64
#
#
# File name: products
# Missing values:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %% [markdown]
# ### Duplicates

# %%
def check_duplicates(data): 
    print('Duplicated rows: ', data.duplicated().sum())

# %%
for i in range(len(df_list)): 
    print(f'File name: {files[i]}')
    check_missing_values(df_list[i])
    check_duplicates(df_list[i])
    print('\n')
# Out:
# File name: orderlines
# Missing values:
# id                  0
# id_order            0
# product_id          0
# product_quantity    0
# sku                 0
# unit_price          0
# date                0
# dtype: int64
# Duplicated rows:  0
#
#
# File name: orders
# Missing values:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64
# Duplicated rows:  0
#
#
# File name: brands
# Missing values:
# short    0
# long     0
# dtype: int64
# Duplicated rows:  0
#
#
# File name: products
# Missing values:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64
# Duplicated rows:  8746

# %% [markdown]
# Based on our initial exploration we need to find a way to deal with our missing values.
#
# Do we have other problems like data inconsistency?
#
# * Example: problems with the `price` column in the `orderlines` dataframe.

# %% [markdown]
# ### Data inconsistency

# %%
for i in range(len(df_list)): 
    
    print(f'File name: {files[i]}')
    check_missing_values(df_list[i])
    check_duplicates(df_list[i])
    df_list[i].info()
    print('\n')
# Out:
# File name: orderlines
# Missing values:
# id                  0
# id_order            0
# product_id          0
# product_quantity    0
# sku                 0
# unit_price          0
# date                0
# dtype: int64
# Duplicated rows:  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB
#
#
# File name: orders
# Missing values:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64
# Duplicated rows:  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB
#
#
# File name: brands
# Missing values:
# short    0
# long     0
# dtype: int64
# Duplicated rows:  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.0+ KB
#
#
# File name: products
# Missing values:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64
# Duplicated rows:  8746
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# Some aspects that do not make a lot of sense:
#
# * **products**:
#     * `price` and `promo_price` are loaded as objects. They should be floats.
#     * Quite a lot of missing values:
#         * `description`: 7 missing values. Maybe that could be inferred from the product name?
#         * `price`: the missing values could be filled from the `orderlines` dataset. But first we will need to clean it.
#
#
# * **orders**:
#     * `created_date` should have a date data type. Then, it would be a good quality check to see if the created date for `orders` mathces with the created dates for `orderlines`.
#
#
# * **orderlines**:
#     * `unit_price` has to be a float, something wrong there.
#     * `date` has to be transformed to a date data type. Then, as we said, check that it with matches with the `orders` dataset.
#
#
# * **brands**: looks fine.
#
#
# Where do we have to start? Since `orders` and `orderlines` seem very crucial to the analysis, we will start by checking that they match.

# %% [markdown]
# ## Cleaning orders

# %%
# change date datatype
orders['created_date'] = pd.to_datetime(orders['created_date'])

# %% [markdown]
# Some data I could extract from here to do a data quality check with `orderlines`:
#
# * the sum of `total_paid` on both datasets should be the same
# * the initial and last date should be the same

# %%
min(orders['created_date'])
# Out:
# Timestamp('2017-01-01 00:07:19')

# %%
max(orders['created_date'])
# Out:
# Timestamp('2018-03-14 13:58:36')

# %%
sum(orders['total_paid'])
# Out:
# nan

# %% [markdown]
# I forgot to deal with missing values on our orders dataset!

# %%
orders.isna().sum()
# Out:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64

# %%
# let's filter them out
orders.loc[orders['total_paid'].isna()]
# Out:
#         order_id        created_date  total_paid    state
# 127701    427314 2017-11-20 18:54:39         NaN  Pending
# 132013    431655 2017-11-22 12:15:24         NaN  Pending
# 147316    447411 2017-11-27 10:32:37         NaN  Pending
# 148833    448966 2017-11-27 18:54:15         NaN  Pending
# 149434    449596 2017-11-27 21:52:08         NaN  Pending

# %% [markdown]
# These orders have a state of "Pending", so I can exclude them from our dataset. We are interested on the completed ones.

# %%
orders.dropna(inplace=True)

# %% [markdown]
# Now my dataset is clean. And the total paid is:

# %%
orders['total_paid'].sum()
# Out:
# 129159615.07000001

# %% [markdown]
# ## Cleaning orderlines

# %% [markdown]
# First let's transform our date time.

# %%
orderlines['date'] = pd.to_datetime(orderlines['date'])

# %%
min(orderlines['date'])
# orders: Timestamp('2017-01-01 00:07:19')
# Out:
# Timestamp('2017-01-01 00:07:19')

# %%
max(orderlines['date'])
# orders: Timestamp('2018-03-14 13:58:36')
# Out:
# Timestamp('2018-03-14 13:58:36')

# %% [markdown]
# Yes, it seems it match. Now let's test our total_paid.
#
# To get this value, we will have to calculate a new column, total price for each row. It would be `product_quantity` * `unit_price`. I can not multiply a two different types of data. So I will have to transform the unit price to a numeric one.

# %%
# orderlines['product_quantity'] * pd.to_numeric(orderlines['unit_price'])

# %% [markdown]
# While trying to transform this column to numeric an error appears. From the error message, "Unable to parse string "1.137.99" at position 6", it seems that our dataset has some problems with the thousands separators: they were encoded as dots, and python only admits one dot per number: the _decimal_ separator!
#
# There are a lot of different ways to solve this problem. The first thing I will do is to count how many dots appear for each number using string operations. If price has more than one dot, I will consider it corrupted.

# %%
# we create a copy of the dataset
ol_temp = orderlines.copy()

# create a new column with the amount of dots in the unit_price column
ol_temp['dots'] = orderlines['unit_price'].str.count('\.')

# show the rows with more than one dot
ol_temp.query('dots > 1')
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 6       1119115    299544           0                 1  APP1582   1.137.99
# 11      1119126    299549           0                 1  PAC0929   2.565.99
# 15      1119131    299553           0                 1  APP1854   3.278.99
# 43      1119195    299582           0                 1  PAC0961   2.616.99
# 59      1119214    299596           0                 1  PAC1599   2.873.99
# ...         ...       ...         ...               ...      ...        ...
# 293862  1649999    452946           0                 1  APP2075   2.999.00
# 293887  1650045    527321           0                 1  PAC2148   3.497.00
# 293889  1650050    527324           0                 1  PAC2117   3.075.00
# 293911  1650088    527342           0                 1  APP2492   1.329.00
# 293936  1650135    527364           0                 1  APP2491   1.329.00
#
#                       date  dots
# 6      2017-01-01 01:17:21     2
# 11     2017-01-01 02:07:42     2
# 15     2017-01-01 02:14:47     2
# 43     2017-01-01 08:54:00     2
# 59     2017-01-01 09:53:11     2
# ...                    ...   ...
# 293862 2018-03-14 13:03:33     2
# 293887 2018-03-14 13:10:15     2
# 293889 2018-03-14 13:10:56     2
# 293911 2018-03-14 13:24:51     2
# 293936 2018-03-14 13:36:13     2
#
# [36169 rows x 8 columns]

# %% [markdown]
# Our theory about the thousands separators is confirmed. How can we solve this problem?
#
# My approach would be to remove all the dots for all the unit_prices, and then add a dot before the last 2 digits to all the rows. Then I will transform it into numeric values.

# %%
orderlines = orderlines.assign(unit_price_nd = orderlines['unit_price'].str.replace('\.','', regex=True))
orderlines.head()
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
# 4  1119113    299543           0                 1  JBL0104      23.74
#
#                  date unit_price_nd
# 0 2017-01-01 00:07:19          1899
# 1 2017-01-01 00:19:45         39900
# 2 2017-01-01 00:20:57         47405
# 3 2017-01-01 00:51:40          6839
# 4 2017-01-01 01:06:38          2374

# %%
orderlines['digits'] = orderlines['unit_price_nd'].str[-2:]
orderlines['integers'] = orderlines['unit_price_nd'].str[:-2]
orderlines.head()
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
# 4  1119113    299543           0                 1  JBL0104      23.74
#
#                  date unit_price_nd digits integers
# 0 2017-01-01 00:07:19          1899     99       18
# 1 2017-01-01 00:19:45         39900     00      399
# 2 2017-01-01 00:20:57         47405     05      474
# 3 2017-01-01 00:51:40          6839     39       68
# 4 2017-01-01 01:06:38          2374     74       23

# %%
orderlines['new_unit_price'] = orderlines['integers'] + '.' + orderlines['digits']
orderlines.head()
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
# 4  1119113    299543           0                 1  JBL0104      23.74
#
#                  date unit_price_nd digits integers new_unit_price
# 0 2017-01-01 00:07:19          1899     99       18          18.99
# 1 2017-01-01 00:19:45         39900     00      399         399.00
# 2 2017-01-01 00:20:57         47405     05      474         474.05
# 3 2017-01-01 00:51:40          6839     39       68          68.39
# 4 2017-01-01 01:06:38          2374     74       23          23.74

# %%
# last step is to transform it to numeric
orderlines['unit_price'] = pd.to_numeric(orderlines['new_unit_price'])
orderlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  float64
#  6   date              293983 non-null  datetime64[ns]
#  7   unit_price_nd     293983 non-null  object
#  8   digits            293983 non-null  object
#  9   integers          293983 non-null  object
#  10  new_unit_price    293983 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 24.7+ MB

# %% [markdown]
# Now it is time to see if it is the same than the orders files.

# %%
orderlines.drop(['unit_price_nd','digits','integers','new_unit_price'], axis=1, inplace=True)

orderlines['total_price'] = orderlines['product_quantity'] * orderlines['unit_price']
sum(orderlines['total_price'])
# 129159615.07000001
# Out:
# 128776222.0298095

# %% [markdown]
# What!? After all this work the values do not match! How can we figure it out where is the problem?

# %% [markdown]
# ## Matching `orders` and `orderlines`
#
# It is possible that some orders exist in one dataset but not in the other one. This would be a potential source for this price mismatch. Let's solve it!

# %% [markdown]
# We first create a new column in the `orderlines` dataset using `assign`. We also use `isin()` to create a boolen value (True/False) that checks whether the `id_order` is present in the `orders` dataset:

# %%
orderlines.assign(check_orders = orderlines['id_order'].isin(orders['order_id']))
# Out:
#              id  id_order  product_id  product_quantity      sku  unit_price  \
# 0       1119109    299539           0                 1  OTT0133       18.99
# 1       1119110    299540           0                 1  LGE0043      399.00
# 2       1119111    299541           0                 1  PAR0071      474.05
# 3       1119112    299542           0                 1  WDT0315       68.39
# 4       1119113    299543           0                 1  JBL0104       23.74
# ...         ...       ...         ...               ...      ...         ...
# 293978  1650199    527398           0                 1  JBL0122       42.99
# 293979  1650200    527399           0                 1  PAC0653      141.58
# 293980  1650201    527400           0                 2  APP0698        9.99
# 293981  1650202    527388           0                 1  BEZ0204       19.99
# 293982  1650203    527401           0                 1  APP0927       13.99
#
#                       date  total_price  check_orders
# 0      2017-01-01 00:07:19        18.99          True
# 1      2017-01-01 00:19:45       399.00          True
# 2      2017-01-01 00:20:57       474.05          True
# 3      2017-01-01 00:51:40        68.39          True
# 4      2017-01-01 01:06:38        23.74          True
# ...                    ...          ...           ...
# 293978 2018-03-14 13:57:25        42.99          True
# 293979 2018-03-14 13:57:34       141.58          True
# 293980 2018-03-14 13:57:41        19.98          True
# 293981 2018-03-14 13:58:01        19.99          True
# 293982 2018-03-14 13:58:36        13.99          True
#
# [293983 rows x 9 columns]

# %% [markdown]
# Then, using `.query` we select rows where the value in this new column is `False`:

# %%
(
orderlines
    .assign(check_orders = orderlines['id_order'].isin(orders['order_id']))
    .query("check_orders==False")
)
# Out:
#              id  id_order  product_id  product_quantity      sku  unit_price  \
# 5       1119114    295310           0                10  WDT0249      231.79
# 63      1119218    296284           0                 1  BNQ0042      699.00
# 67      1119223    294806           0                 1  APP1849     2558.99
# 69      1119226    294806           0                 1  APP1864     2797.99
# 70      1119235    297261           0                 1  QNA0177      304.99
# ...         ...       ...         ...               ...      ...         ...
# 275665  1621177    244328           0                 1  OWC0260      349.00
# 280055  1628699    261391           0                 1  APP2352     3343.00
# 280352  1629247    287797           0                 1  SYN0182      484.11
# 280856  1630150    261391           0                 1  SAT0091       44.99
# 280869  1630178    261391           0                 1  SAT0062       49.99
#
#                       date  total_price  check_orders
# 5      2017-01-01 01:14:27      2317.90         False
# 63     2017-01-01 09:58:35       699.00         False
# 67     2017-01-01 10:09:15      2558.99         False
# 69     2017-01-01 10:15:14      2797.99         False
# 70     2017-01-01 10:17:59       304.99         False
# ...                    ...          ...           ...
# 275665 2018-02-20 13:00:45       349.00         False
# 280055 2018-02-27 11:43:25      3343.00         False
# 280352 2018-02-27 19:16:26       484.11         False
# 280856 2018-02-28 12:18:26        44.99         False
# 280869 2018-02-28 12:30:57        49.99         False
#
# [240 rows x 9 columns]

# %% [markdown]
# It looks like 234 rows in `orderlines` come from orders not present in the `orders` dataset. This is quite inconsistent, since the `orders` dataset should be the one and only source of truth for orders: if an order is not there, it should not exist. We will try to find out why that happened, but for now, let's just remove those "ghost" orders:

# %%
orderlines = (orderlines
              .assign(check_orders = orderlines['id_order'].isin(orders['order_id']))
              .query("check_orders==True"))

# %% [markdown]
# Now let's look at this problem in the opposite direction: are there orders in the `orders` dataset not prsent in `orderlines`?

# %%
(orders
 .assign(check_orders = orders['order_id'].isin(orderlines['id_order']))
 .query("check_orders==False"))
# Out:
#         order_id        created_date  total_paid            state  \
# 8         245941 2017-01-01 10:32:23      183.52        Completed
# 65        268629 2017-01-31 11:27:25       73.23        Completed
# 75        272862 2017-04-18 18:17:10      128.99          Pending
# 82        277655 2017-02-01 08:44:55        9.99          Pending
# 83        277994 2017-01-23 18:30:11       52.99        Completed
# ...          ...                 ...         ...              ...
# 226835    527328 2018-03-14 13:14:12        0.00  Shopping Basket
# 226851    527344 2018-03-14 13:25:21        0.00      Place Order
# 226853    527346 2018-03-14 13:26:14        0.00      Place Order
# 226855    527348 2018-03-14 13:28:18        0.00      Place Order
# 226889    527382 2018-03-14 13:47:43        0.00  Shopping Basket
#
#         check_orders
# 8              False
# 65             False
# 75             False
# 82             False
# 83             False
# ...              ...
# 226835         False
# 226851         False
# 226853         False
# 226855         False
# 226889         False
#
# [22213 rows x 5 columns]

# %% [markdown]
# There are more than 22000 orders in the `orders` dataset that are not present on the `orderlines` dataset!!! We can try to find out why by looking at the state of these orders:

# %%
(orders
 .assign(check_orders = orders['order_id'].isin(orderlines['id_order']))
 .query("check_orders==False")
 ['state'].value_counts())
# Out:
# Place Order        12304
# Shopping Basket     9810
# Completed             45
# Cancelled             41
# Pending               13
# Name: state, dtype: int64

# %% [markdown]
# It looks like most of them are orders that were not fully completed: the products were left in the shopping basket or the order was "placed" but maybe not paid (hence the state "Place Order". Some of them were "Completed", though.
#
# This will require further research, and we might have to come back to these orders if we have to explore consumer behaviour (e.g. why are orders left in the shopping basket?), but for now, for the sake of data quality, let's drop all of these unmatched orders:

# %%
orders = (orders
          .assign(check_orders = orders['order_id'].isin(orderlines['id_order']))
          .query("check_orders==True")
         )

# %% [markdown]
# Let's now check again if the total paid matches:

# %%
orders['total_paid'].sum()
# Out:
# 129130877.18

# %%
orderlines['total_price'].sum()
# Out:
# 128659393.77

# %% [markdown]
# STILL NOT MATCHING!!! This is outrageous. Let's keep exploring.

# %% [markdown]
# ## Solving the price mismatch
#
# Let's merge both datasets and compare, order by order, the `total_price`. We will call this new merged dataset `orders_info`.
#
# *Note: To merge `orderlines` with `orders`, we have to group and aggregate `orderlines`!

# %%
orders_info = (
orderlines
    .groupby('id_order')
    .agg({'total_price':'sum'})
    .merge(orders, how='left', left_on='id_order', right_on='order_id')
    .copy()
)
orders_info
# Out:
#         total_price  order_id        created_date  total_paid  \
# 0             44.99    241319 2017-01-02 13:35:40       44.99
# 1            129.16    241423 2017-11-06 13:10:02      136.15
# 2             10.77    242832 2017-12-31 17:40:03       15.76
# 3             77.99    243330 2017-02-16 10:59:38       84.98
# 4            153.87    243784 2017-11-24 13:35:19      157.86
# ...             ...       ...                 ...         ...
# 204686        42.99    527397 2018-03-14 13:56:38       42.99
# 204687        42.99    527398 2018-03-14 13:57:25       42.99
# 204688       141.58    527399 2018-03-14 13:57:34      141.58
# 204689        19.98    527400 2018-03-14 13:57:41       19.98
# 204690        13.99    527401 2018-03-14 13:58:36       18.98
#
#                   state  check_orders
# 0             Cancelled          True
# 1             Completed          True
# 2             Completed          True
# 3             Completed          True
# 4             Cancelled          True
# ...                 ...           ...
# 204686      Place Order          True
# 204687  Shopping Basket          True
# 204688  Shopping Basket          True
# 204689  Shopping Basket          True
# 204690      Place Order          True
#
# [204691 rows x 6 columns]

# %% [markdown]
# Now that the `total` from both datasets is in the same dataframe, we can create a new column with the difference:

# %%
orders_info['price_difference'] = orders_info['total_price'] - orders_info['total_paid']
orders_info.sort_values('price_difference').tail(30)
# Out:
#         total_price  order_id        created_date  total_paid  \
# 20654        164.90    322147 2017-02-10 11:56:59      125.99
# 11725        164.90    312311 2017-01-20 00:59:54      125.99
# 45940         44.99    349377 2017-04-24 21:42:28        4.99
# 8545         164.90    308825 2017-01-13 14:27:46      123.99
# 13784        164.90    314570 2017-01-25 09:01:35      122.99
# 21347        164.90    322901 2017-02-12 13:25:12      122.99
# 25517        164.90    327363 2017-02-21 22:42:17      122.99
# 986          164.90    300474 2017-01-02 12:24:54      119.00
# 166458    214768.02    484334 2018-01-07 15:58:26   214714.31
# 54853      13450.87    359083 2017-05-25 13:58:31    13391.86
# 134183       341.98    448286 2017-11-27 14:04:40      275.99
# 18563        142.44    319901 2017-02-04 16:09:34       60.43
# 14391        151.99    315229 2017-01-31 10:57:07       66.98
# 148204        89.99    463567 2017-12-15 09:45:36        0.00
# 111          135.97    289685 2017-01-09 23:15:07       15.95
# 102967       441.12    412943 2017-10-16 09:51:14      290.54
# 120052       426.86    432303 2017-11-22 21:43:02      261.86
# 46945        339.99    350460 2017-04-27 18:44:21        6.99
# 141740       359.99    456491 2017-12-06 20:43:59        0.00
# 151599       770.98    467341 2017-12-19 23:10:24      408.98
# 194349       388.06    515818 2018-02-22 01:02:35        6.59
# 186388      1124.00    506820 2018-02-06 13:34:20        1.33
# 179022      1558.00    498550 2018-01-25 17:57:06        3.81
# 162308      1958.36    479621 2018-01-02 13:33:37       26.38
# 201739      1968.00    524152 2018-03-09 21:00:48        6.59
# 192913      2342.00    514198 2018-02-19 11:40:55        6.59
# 193911      3038.00    515325 2018-02-21 11:31:20       13.19
# 188169      3112.59    508818 2018-02-09 13:43:30        6.59
# 197889      7771.23    519801 2018-03-02 08:59:34       31.22
# 56804     250802.37    361200 2017-06-01 11:55:02   214642.47
#
#                   state  check_orders  price_difference
# 20654         Completed          True             38.91
# 11725         Completed          True             38.91
# 45940           Pending          True             40.00
# 8545          Completed          True             40.91
# 13784         Completed          True             41.91
# 21347       Place Order          True             41.91
# 25517         Completed          True             41.91
# 986           Completed          True             45.90
# 166458  Shopping Basket          True             53.71
# 54853   Shopping Basket          True             59.01
# 134183      Place Order          True             65.99
# 18563         Completed          True             82.01
# 14391         Cancelled          True             85.01
# 148204  Shopping Basket          True             89.99
# 111           Completed          True            120.02
# 102967  Shopping Basket          True            150.58
# 120052        Completed          True            165.00
# 46945         Cancelled          True            333.00
# 141740  Shopping Basket          True            359.99
# 151599  Shopping Basket          True            362.00
# 194349  Shopping Basket          True            381.47
# 186388  Shopping Basket          True           1122.67
# 179022  Shopping Basket          True           1554.19
# 162308  Shopping Basket          True           1931.98
# 201739  Shopping Basket          True           1961.41
# 192913  Shopping Basket          True           2335.41
# 193911  Shopping Basket          True           3024.81
# 188169  Shopping Basket          True           3106.00
# 197889  Shopping Basket          True           7740.01
# 56804   Shopping Basket          True          36159.90

# %%
orders_info['price_difference'].describe()
# Out:
# count    204691.000000
# mean         -2.303391
# std         297.461827
# min      -90898.610000
# 25%          -0.010000
# 50%           0.000000
# 75%           0.000000
# max       36159.900000
# Name: price_difference, dtype: float64

# %% [markdown]
# Looks like the maximum and minimun price differences are huge: some orders are really corrupted. But we also see from the mean and the quartiles that the price difference is neglegible for most orders.

# %% [markdown]
# ## Challenge: Remove outliers
#
# Decide on a criteria for removing orders whenever you cannot trust the price difference between `orders` and `orderlines`.

# %%
# code here

# %% [markdown]
# Save the data once you are sure you can trust it!

# %%
path = '/Users/ranjitsah/Desktop/project-2/data/clean-data/'
orderlines.to_csv(path + 'orderlines_cl.csv', index=False)
orders.to_csv(path + 'orders_cl.csv', index=False)

# %% [markdown]
# ## Challenge: Cleaning products

# %% [markdown]
# Now it is time to clean the products dataset. Let's do a quick review of the things where wrong:

# %%
print(products.info())
check_duplicates(products)
check_missing_values(products)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB
# None
# Duplicated rows:  8746
# Missing values:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %% [markdown]
# Looking at this overview, we can see that there are different things that has to be changed:
#
# * Data types:
#     * price should be a float
#     * promo price should be a float
# * Duplicated rows. They have to be removed.
#     * To accomplish this step you can use the method `pd.DataFrame.drop_duplicates()`. Be sure you drop all the duplicates based on the column **sku**, as it is the one you will use to merge with orderlines.
# * Missing values:
#     * Description may be can be infered by the name
#     * price. Is there a way we can extract the information from another table?
#     * type. Do we need this column for our analysis?
#
# This task can be accomoplished by using all the methods you already know.

# %% [markdown]
# ### Start of the challenge

# %% [markdown]
# #### Duplicates

# %%
products.drop_duplicates(inplace=True)

# %%
products.shape
# Out:
# (10580, 7)

# %%
products.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99     499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                             mouse Apple USB cable.     59     569.898
# 3              IPhone dock and USB Cable Apple iPod.     25     229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %% [markdown]
# Check if you have a unique description for each sku:

# %%
products.groupby('sku')['sku'].count().sort_values(ascending=False).head(5)
# Out:
# sku
# APP1197    2
# PAC1555    1
# PAC1557    1
# PAC1558    1
# PAC1559    1
# Name: sku, dtype: int64

# %% [markdown]
# The product APP1197 is not unique. Let's zoom in:

# %%
products.query('sku == "APP1197"')
# Out:
#           sku                                               name  \
# 7992  APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display...
# 8000  APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display...
#
#                                                    desc price promo_price  \
# 7992  Desktop Apple iMac 21.5 inch i5 31 GHz Retina ...  1729     1305.59
# 8000  Desktop Apple iMac 21.5 inch i5 31 GHz Retina ...   NaN     1305.59
#
#       in_stock  type
# 7992         0  1282
# 8000         0  1282

# %%
products.drop_duplicates('sku').query('sku == "APP1197"')
# Out:
#           sku                                               name  \
# 7992  APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display...
#
#                                                    desc price promo_price  \
# 7992  Desktop Apple iMac 21.5 inch i5 31 GHz Retina ...  1729     1305.59
#
#       in_stock  type
# 7992         0  1282

# %% [markdown]
# I can drop the duplicates only focusing on the column 'sku':

# %%
products.drop_duplicates('sku', inplace=True)

# %% [markdown]
# #### Data types

# %%
# pd.to_numeric(products['price'])

# %% [markdown]
# It seems this time that the problem in our products prices is different than the one we have found on orderlines. How is it possible we have more than 3 digits?
#
# Let's look at a random sample in our dataframe to understant more about it:

# %%
products.sample(10)
# Out:
#              sku                                               name  \
# 15683    HOC0007  Nike hoco Series Apple Watch Strap 38mm Black ...
# 18640    PAC2486  Synology DS218 NAS Server | 24TB (2x12TB) Seag...
# 18148  LAC0175-A  Open - LaCie Porsche Design Mobile Hard Drive ...
# 11128    CYG0071  Cygnett Luxlink Metal strap for Apple Watch 42...
# 1894   NTE0058-A  Open - NewerTech NuPower Battery 78W MacBook P...
# 12681    MOP0086   Mophie Powerstation 5X battery 10000mAh Aluminum
# 1881   CRU0037-4  Crucial Mac Memory 32GB (4x8GB) 1866MHz DDR3 DIMM
# 432    OWC0039-2    Mac memory OWC 8GB (2x4GB) SO-DIMM DDR3 1600MHZ
# 646      NTE0053       NewerTech miniStack Classic Mac external box
# 19170    BOS0068        Bose Bluetooth Headset Blue SoundSport Free
#
#                                                     desc    price promo_price  \
# 15683             Silicone Strap Sports Watch 38mm Apple       45     269.903
# 18640  2-bay NAS server can accommodate 4K Ultra HD f...  1273.44   1.013.179
# 18148  2TB external USB-open C connection and USB 3.0...   134.99   1.031.143
# 11128  Metal strap for easy installation Apple Watch ...    59.99     389.898
# 1894        Battery MacBook Pro 15-inch Unibody 2011/12.  109.989     873.826
# 12681  aluminum battery ultra thin 10.000mAh 2 USB po...   139.95      125.99
# 1881                      RAM 32GB (4x8GB) Mac Pro 2013.   463.96   4.629.896
# 432    RAM 8GB (2x4GB) MacBook Pro iMac Mac mini (201...    93.98       87.99
# 646            Mac external box 35 FireWire 800 USB 2.0.    64.99     449.878
# 19170  Bose Bluetooth headset with reloadable sheath ...      199      186.99
#
#        in_stock      type
# 15683         1      2449
# 18640         0  12175397
# 18148         0  11935397
# 11128         0      2449
# 1894          0      1298
# 12681         0      1515
# 1881          0      1364
# 432           1      1364
# 646           0  12995397
# 19170         1      5384

# %% [markdown]
# My strategy would be:
#
# 1. Replace missing values with a "special" string. In that case I will put "000.000" as it would represent that this value has a wrong format and has to be changed. This step is done to avoid future problems while cleaning the column price.
# 2. Create a new column called "price_split" with the values of price splited by the `,`
# 3. Create a new column called "dots_count" counting the number of dots a price contains

# %%
import numpy as np

products = (
products
    # Replace all missing values by '000.000'
    .assign(price = lambda x: x['price'].replace(np.nan, '000.000'))
    .assign(price_split = lambda x: x['price'].str.split('\.'),
            dots_count = lambda x: x['price'].str.count('\.'))
)
products.head(10)
# Out:
#          sku                                               name  \
# 0    RAI0007                  Silver Rain Design mStand Support
# 1    APP0023                  Apple Mac Keyboard Keypad Spanish
# 2    APP0025                   Mighty Mouse Apple Mouse for Mac
# 3    APP0072      Apple Dock to USB Cable iPhone and iPod white
# 4    KIN0007        Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# 5    APP0073     Apple Composite AV Cable iPhone and iPod white
# 6    KIN0008        Mac Memory Kingston 1GB 667MHz DDR2 SO-DIMM
# 7    KIN0009        Mac Memory Kingston 2GB 800MHz DDR2 SO-DIMM
# 8  KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# 9    APP0100             Apple Adapter Mini Display Port to VGA
#
#                                                 desc  price promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99     499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                             mouse Apple USB cable.     59     569.898
# 3              IPhone dock and USB Cable Apple iPod.     25     229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# 5  IPhone and iPod AV Cable Dock to Composite Video.     45     420.003
# 6  1GB RAM Mac mini and iMac (2006/07) MacBook Pr...  18.99     146.471
# 7       2GB RAM iMac with Intel Core 2 Duo (Penryn).  36.99     274.694
# 8  RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...     74     669.904
# 9  Adapter Mini Display Port to VGA MacBook and M...     35     330.003
#
#    in_stock      type price_split  dots_count
# 0         1      8696    [59, 99]           1
# 1         0  13855401        [59]           0
# 2         0      1387        [59]           0
# 3         0      1230        [25]           0
# 4         1      1364    [34, 99]           1
# 5         0      1230        [45]           0
# 6         0      1364    [18, 99]           1
# 7         0      1364    [36, 99]           1
# 8         0      1364        [74]           0
# 9         0      1325        [35]           0

# %% [markdown]
# Now I need to look at each value in the new column "price_split" and check the folliwing condition:
#
# If the last element of the value in price split has a length bigger than 2 then add a `True` inside the list `need_check`, else add a `False`.
#
# Example 1:
#
#  - Input: price_split = `[[59],[99]]` The last element of the value in price split is `[99]`. The length of this element is 2, as it only have 2 characters. Then we will append a `False` on the list `need_check`.
#
# Exemple 2:
#
# - Input: price_split = `[[234],[895]]` The last element of the value in price split is `[895]`. The length of the last element is 3, as it has 3 characters. Then we will append a `True` on the list `need_check`.

# %%
need_check = []
len_split = []
for val in products['price_split']:    
    len_split.append(len(val))
    if len(val[-1]) > 2: 
        need_check.append(True)
    else:
        need_check.append(False)

# %% [markdown]
# We have created two lists:
#
# * `need_check`: tells us which element of the dataframe has a last element on `price_split` with a lenght higher than 2.
# * `len_split` : tells us how many elements are inside each `price_split`.
#     * Example 1: `[[59],[99]]` it has a lenght of 2
#     * Example 2: `[59]` it has a lenght of 1
#     * Example 3: `[[654],[998]]` it has a lenght of 2
#     * Example 4: `[[9],[654],[998]]` it has a lenght of 3
#
# Then we can add this elements into our products dataframe to detect these rows:

# %%
(
products
    .assign(need_check = need_check, 
            len_split = len_split)
    .query('need_check==True & len_split > 1 & dots_count != 0')
).head()
# Out:
#          sku                                               name  \
# 34   TWS0019  Twelve South MagicWand support Apple Magic Tra...
# 362  REP0043                      Speaker lower repair iPhone 4
# 480  PIE0011                     Internal Battery for iPhone 3G
# 515  SEN0061  Sennheiser EZX 80 Handsfree iPhone iPad and iP...
# 518  SEV0026  Service installation RAM + HDD + SSD MacBook /...
#
#                                                   desc    price promo_price  \
# 34   MagicWand for wireless keyboard and Magic Trac...  000.000     299.899
# 362  Repair service including parts and labor for i...  499.004     499.004
# 480        Replacement AC Adapter for Apple iPhone 3G.   98.978      98.978
# 515  IPhone bluetooth headset with microphone iPad ...  649.891     649.891
# 518  RAM + HDD installation + SSD in your MacBook /...  599.918     599.918
#
#      in_stock      type price_split  dots_count  need_check  len_split
# 34          0      8696  [000, 000]           1        True          2
# 362         0  1,44E+11  [499, 004]           1        True          2
# 480         0  21485407   [98, 978]           1        True          2
# 515         0      5384  [649, 891]           1        True          2
# 518         0  20642062  [599, 918]           1        True          2

# %% [markdown]
# By defining a set of rules, I can quickly detect the prices that are giving me errors. Those rules are:
#
# * The length of the last element on the value `price_split` has a lenght bigger than 2 (This is what the column `need_check` is telling us).
# * There is more than 1 element inside the column `price_split` (Information given by the column `len_split`).
# * The number of dots in price is different than 0 (Column `dots_count`).
#
# The next steps would be to use this conditions to replace this values by missing values. To do it, I am going to use the function from the module `numpy` called `np.where`. It works as an `if else` statement; if a condition is accomplished, then return a value, else, return another.

# %%
products = (
products
    .assign(need_check = need_check, 
            len_split = len_split)
    .assign(
        price = lambda x: pd.to_numeric(
            np.where((x['need_check']==True) & (x['len_split'] > 1) & (x['dots_count'] != 0), np.nan, x['price'])
        )
    )
)
products.query('need_check==True & len_split > 1 & dots_count != 0').sample(10)
# Out:
#              sku                                               name  \
# 15476    REP0335                      Repair iPad 3 Headphone Input
# 14921    PAC1901  Crucial SSD expansion kit MX300 525GB + 8GB RA...
# 15349    REP0364                      iPad mini front camera repair
# 12069    CEL0035  Celly Ambo cover with lid iPhone 6 / 6S Plus B...
# 11501    PAC1251  Samsung SSD 850 expansion kit PRO 1TB + 16GB 1...
# 10745  BEL0145-A  Open - Belkin Switch + Motion WeMO Wi-Fi contr...
# 2007     PAC0740  Samsung EVO SSD expansion kit 250GB + 16GB 160...
# 12072    CEL0052   Celly 4000mAh Battery Power Bank Aluminum Silver
# 15431    REP0378                    Touch Screen Repair iPad Mini 3
# 11190    PAC1656       QNAP TS-253A | 16GB RAM | 8TB (2x4TB) WD Red
#
#                                                     desc  price promo_price  \
# 15476  Repair service including parts and labor for i...    NaN       69.99
# 14921  525GB + SSD expansion 8GB 1600Mhz RAM for Mac ...    NaN   2.805.845
# 15349  Repair service including parts and labor for i...    NaN       69.99
# 12069  Imiatación cover skin with removable lid for i...    NaN     199.904
# 11501  SSD upgrade kit 1TB + 16GB 1600Mhz RAM for Mac...    NaN     626.584
# 10745    Kit + motion switch for sensor devices via App.    NaN     254.736
# 2007   SSD upgrade kit 250GB + 16GB 1600Mhz RAM for M...    NaN   2.895.845
# 12072  external battery capacity 4000mAh output volta...    NaN     199.892
# 15431  Repair service including parts and labor for i...    NaN   1.299.903
# 11190  NAS with 16GB of RAM memory + 8TB (2x4TB) Netw...    NaN   8.711.794
#
#        in_stock      type    price_split  dots_count  need_check  len_split
# 15476         0  1,44E+11  [6, 999, 003]           2        True          3
# 14921         0      1433  [3, 116, 285]           2        True          3
# 15349         0  1,44E+11  [6, 999, 003]           2        True          3
# 12069         0  11865403     [000, 000]           1        True          2
# 11501         0      1433  [6, 989, 592]           2        True          3
# 10745         0      1298     [999, 944]           1        True          2
# 2007          1      1433  [3, 269, 592]           2        True          3
# 12072         0      1515     [000, 000]           1        True          2
# 15431         0  1,44E+11  [1, 299, 903]           2        True          3
# 11190         1  12175397  [9, 260, 782]           2        True          3

# %% [markdown]
# As you can see, we replaced all the values with wrong prices with missing data. New let's drop all the columns we do not need:

# %%
products.drop(['price_split','need_check','len_split','dots_count'], axis=1, inplace=True)
check_missing_values(products)
# Out:
# Missing values:
# sku              0
# name             0
# desc             7
# price          587
# promo_price      0
# in_stock         0
# type            50
# dtype: int64

# %% [markdown]
# And now is time to find a strategy to fill this missing values.

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10579 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10579 non-null  object
#  1   name         10579 non-null  object
#  2   desc         10572 non-null  object
#  3   price        9992 non-null   float64
#  4   promo_price  10579 non-null  object
#  5   in_stock     10579 non-null  int64
#  6   type         10529 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 661.2+ KB

# %% [markdown]
# #### Missing values

# %% [markdown]
# As now we have incremented the number of missing data (we transformed all the wrong prices to missing ones) let's find out an strategy to fill them.
#
# But first, let's look if they are important in our dataset:

# %%
prod_na = products.loc[products.isna().sum(axis=1) > 0,:].copy()
prod_na
# Out:
#            sku                                               name  \
# 34     TWS0019  Twelve South MagicWand support Apple Magic Tra...
# 307    SAN0017       SanDisk Cruzer Edge USB 2.0 Flash Drive 16GB
# 362    REP0043                      Speaker lower repair iPhone 4
# 480    PIE0011                     Internal Battery for iPhone 3G
# 515    SEN0061  Sennheiser EZX 80 Handsfree iPhone iPad and iP...
# ...        ...                                                ...
# 19312  REP0424                       Input repair Headphones iPad
# 19313  REP0421                     iPad charging connector repair
# 19314  REP0416                           iPad front camera repair
# 19315  REP0413                            repair rear camera iPad
# 19316  REP0407                                iPad battery repair
#
#                                                     desc  price promo_price  \
# 34     MagicWand for wireless keyboard and Magic Trac...    NaN     299.899
# 307                         Pendrive USB 2.0 Mac and PC.    8.0      59.895
# 362    Repair service including parts and labor for i...    NaN     499.004
# 480          Replacement AC Adapter for Apple iPhone 3G.    NaN      98.978
# 515    IPhone bluetooth headset with microphone iPad ...    NaN     649.891
# ...                                                  ...    ...         ...
# 19312  Repair service including parts and labor for iPad    NaN       69.99
# 19313  Repair service including parts and labor for iPad    NaN       69.99
# 19314  Repair service including parts and labor for iPad    NaN       69.99
# 19315  Repair service including parts and labor for iPad    NaN       69.99
# 19316  Repair service including parts and labor for iPad    NaN       69.99
#
#        in_stock      type
# 34            0      8696
# 307           0       NaN
# 362           0  1,44E+11
# 480           0  21485407
# 515           0      5384
# ...         ...       ...
# 19312         0  1,44E+11
# 19313         0  1,44E+11
# 19314         0  1,44E+11
# 19315         0  1,44E+11
# 19316         0  1,44E+11
#
# [639 rows x 7 columns]

# %% [markdown]
# Decide which percentage of the data represents. Always think smart about using your time:
#
# * Which % of the orders contains one of these products? In that case I has to look at orderlines.

# %%
orderlines.shape[0]
# Out:
# 293743

# %%
# percentage of orders with products with missing prices on products dataset
orderlines.loc[orderlines['sku'].isin(prod_na['sku']),:].shape[0] / orderlines.shape[0]
# Out:
# 0.025604014393534484

# %%
# this is interesting, as for the products data the percentage is much smaller
prod_na.shape[0] / products.shape[0]
# Out:
# 0.06040268456375839

# %% [markdown]
# Which impact has on the total revenue?

# %%
orderlines.loc[orderlines['sku'].isin(prod_na['sku']),:]['total_price'].sum() / orderlines['total_price'].sum()
# Out:
# 0.027227081578374515

# %% [markdown]
# With a 3% only on the total revenue, but we are considering all the orders, and we are interested on the completed ones.

# %%
na_skus = prod_na['sku'].tolist()

(
orderlines
    .merge(orders, how='left', left_on='id_order', right_on='order_id')
    .query('state == "Completed" & sku == @na_skus')
    ['total_price'].sum()
) / (
orderlines
    .merge(orders, how='left', left_on='id_order', right_on='order_id')
    .query('state == "Completed"')
    ['total_price'].sum()
)
# Out:
# 0.02922734355997912

# %% [markdown]
# As you can see, the products that are missing only represents 2.9% of the total invoice.
# I will not drop them, as it still has some information which I would like to keep it to create categories (sku, item name and item description), so I am going to save it with prices as missing values. But I will add an extra column telling me which is the maximum price for these skus in orderlines.

# %%
# find out which sku are missing in products
prod_na_list = (
products
    .loc[products['price'].isna(),'sku']
    .tolist()
)

# find them on orderlines, and aggregate the information to find the maximum value
orderlines_prod_na_max = (
orderlines
    .query("sku == @prod_na_list")
    .groupby('sku') 
    .agg({'unit_price':'max'})
    .rename(columns={'unit_price':'max_price_orderlines'})
    .reset_index()
)
orderlines_prod_na_max[:5]
# Out:
#          sku  max_price_orderlines
# 0  ADN0023-A                 16.81
# 1  APP0660-A                253.11
# 2    APP0869                539.00
# 3    APP0870                539.00
# 4    APP0871                539.00

# %% [markdown]
# Time to add the column `max_price_orderlines` in our products data:

# %%
products = (
products
    .merge(orderlines_prod_na_max, how='left',on='sku')
)
products.loc[products['max_price_orderlines'].notna()].sample(10)
# Out:
#             sku                                               name  \
# 4333    CEL0046        Laser Case Celly iPhone 6 / 6S Clear Silver
# 4990    PAC2027  Synology DS216 + II | Seagate 4TB IronWolf for...
# 7533    PAC1975  Synology DS1817 + | 8GB RAM | 32TB (8x4TB) WD Red
# 6476    PAC1905  Crucial SSD expansion kit MX300 525GB + 16GB 1...
# 377     SEV0029                Apple MacBook repair Budget Request
# 5301    PAC1510                           QNAP TS-251A 8GB RAM NAS
# 6118    PAC1558  SSD Crucial MX300 expansion kit 1TB + 16GB 160...
# 1721    CEL0012            Celly Silicone Hard Shell iPhone 6 Blue
# 4318    CEL0058         Celly IceCube Case iPhone 6 / 6S Plus Rosa
# 8648  OWC0190-A       Open - Mac OWC Memory 16GB 1333MHZ DDR3 DIMM
#
#                                                    desc  price promo_price  \
# 4333                Protective Case for iPhone 6 and 6s    NaN     149.895
# 4990  Synology DS216 + II with 2GB of RAM and 6TB (2...    NaN   5.831.789
# 7533           NAS with 8GB RAM and 32TB for Mac and PC    NaN  20.797.456
# 6476  525GB + SSD expansion 16GB 1600Mhz RAM for Mac...    NaN   3.475.846
# 377                           MacBook repair diagnosis.    NaN     199.892
# 5301  NAS with 8GB of RAM and USB port for direct ac...    NaN   3.979.896
# 6118  SSD upgrade kit 1TB + 16GB 1600MHz RAM for Mac...    NaN   4.675.839
# 1721                      Hard Shell Silicone iPhone 6.    NaN        4.99
# 4318             Anti-shock Case for iPhone 6 / 6S Plus    NaN      99.898
# 8648       16GB RAM for Mac Pro 2010/2012 Reconditioned    NaN     967.572
#
#       in_stock      type  max_price_orderlines
# 4333         0  11865403                 14.99
# 4990         0  12175397                599.18
# 7533         0  12175397               2068.99
# 6476         0      1433                343.58
# 377          0  1,46E+11                 19.99
# 5301         0  12175397                374.99
# 6118         1      1433                508.58
# 1721         0  11865403                  4.99
# 4318         0  11865403                  9.99
# 8648         0      1364                 96.76

# %% [markdown]
# And not let's store it as a products clean csv into our path:

# %%
products.drop(['promo_price','in_stock','type'], axis=1).to_csv(path + 'products_cl.csv', index=False)

# %% [markdown]
# ## Brands

# %% [markdown]
# The brands csv looks fine, so we can work together with it.

# %%
brands.to_csv(path + 'brands_cl.csv', index=False)
